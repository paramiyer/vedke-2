# %%
import os, json
from pathlib import Path
from openai import OpenAI
import requests

# %%
API_KEY = "sk_9yjle41z_NYxdjePjYKPiGu0F6PFoBU8Y" 
HEADERS = {"api-subscription-key": API_KEY, "Content-Type": "application/json"}

init_url = "https://api.sarvam.ai/speech-to-text/job/v1"

payload = {
    "job_parameters": {
        # keep minimal first; add model/mode only if docs list them as valid
         "model": "saaras:v3",
        "mode": "verbatim",
        "language_code" :"sa-IN",
        "with_timestamps":True,
        "num_speakers":1
    }
}

r = requests.post(init_url, headers=HEADERS, json=payload, timeout=60)
print("init:", r.status_code, r.text[:800])
r.raise_for_status()

job = r.json()
JOB_ID = job["job_id"]
print("JOB_ID:", JOB_ID)
# Out:
# init: 202 {"job_id":"20260305_ef61b052-ec65-443b-9be1-7edd1f651b63","storage_container_type":"Azure_V1","job_parameters":{"language_code":"sa-IN","model":"saaras:v3","mode":"verbatim","with_timestamps":true,"with_diarization":false,"num_speakers":1,"input_audio_codec":null},"job_state":"Accepted"}
# JOB_ID: 20260305_ef61b052-ec65-443b-9be1-7edd1f651b63

# %%
import os, time, json, requests
from pathlib import Path

HEADERS_JSON = {"api-subscription-key": API_KEY, "Content-Type": "application/json"}
HEADERS_KEYONLY = {"api-subscription-key": API_KEY}

JOB_ID = "20260305_ef61b052-ec65-443b-9be1-7edd1f651b63"  # from your init response
AUDIO_PATH = Path("/Users/parameshwaraniyer/Documents/code/vedke-2/data/audio.mp3")
assert AUDIO_PATH.exists(), AUDIO_PATH

# %%
upload_meta = requests.post(
    "https://api.sarvam.ai/speech-to-text/job/v1/upload-files",
    headers=HEADERS_JSON,
    json={"job_id": JOB_ID, "files": [AUDIO_PATH.name]},
    timeout=60
)
print("upload-files:", upload_meta.status_code, upload_meta.text[:500])
upload_meta.raise_for_status()

upload_info = upload_meta.json()
put_url = upload_info["upload_urls"][AUDIO_PATH.name]
print("Got PUT URL for:", AUDIO_PATH.name)
# Out:
# upload-files: 200 {"job_id":"20260305_ef61b052-ec65-443b-9be1-7edd1f651b63","job_state":"Accepted","upload_urls":{"audio.mp3":{"file_url":"https://appsprodpublicsa.blob.core.windows.net/bulk-upload-storage/jobs/2026-03-05/SPEECH_TO_TEXT_BULK/ef61b052-ec65-443b-9be1-7edd1f651b63/inputs/audio.mp3?se=2026-03-05T23%3A06%3A58Z&sp=w&sv=2025-05-05&sr=b&sig=9pVsj2sGVrlH69DN4JPYBKj3mAUF0Sd0CbSMQaZuOkY%3D","file_metadata":null}},"storage_container_type":"Azure_V1"}
# Got PUT URL for: audio.mp3

# %%
import requests
from pathlib import Path

AUDIO_PATH = Path("/Users/parameshwaraniyer/Documents/code/vedke-2/data/audio.mp3")

upload_info = upload_meta.json()
u = upload_info["upload_urls"][AUDIO_PATH.name]

# u might be a string OR a dict with file_url
put_url = u["file_url"] if isinstance(u, dict) else u
print("PUT URL:", put_url[:120], "...")

with AUDIO_PATH.open("rb") as f:
    put = requests.put(
        put_url,
        data=f,
        headers={
            "x-ms-blob-type": "BlockBlob",
            "Content-Type": "audio/mpeg",
        },
        timeout=300
    )

print("PUT:", put.status_code, put.text[:200])
put.raise_for_status()
print("Upload done.")
# Out:
# PUT URL: https://appsprodpublicsa.blob.core.windows.net/bulk-upload-storage/jobs/2026-03-05/SPEECH_TO_TEXT_BULK/ef61b052-ec65-443 ...
# PUT: 201
# Upload done.

# %%
start = requests.post(
    f"https://api.sarvam.ai/speech-to-text/job/v1/{JOB_ID}/start",
    headers=HEADERS_KEYONLY,
    timeout=60
)
print("start:", start.status_code, start.text[:500])
start.raise_for_status()
# Out:
# start: 200 {"job_state":"Pending","created_at":"2026-03-05T22:06:21.189764+00:00","updated_at":"2026-03-05T22:07:16.143670+00:00","job_id":"20260305_ef61b052-ec65-443b-9be1-7edd1f651b63","total_files":1,"successful_files_count":0,"failed_files_count":0,"storage_container_type":"Azure_V1","error_message":"","job_details":[]}

# %%
def poll_status(job_id: str, sleep_s: float = 3.0, max_wait_s: float = 30*60):
    t0 = time.time()
    while True:
        r = requests.get(
            f"https://api.sarvam.ai/speech-to-text/job/v1/{job_id}/status",
            headers=HEADERS_KEYONLY,
            timeout=60
        )
        r.raise_for_status()
        st = r.json()
        state = st.get("job_state")
        print("state:", state, "| success:", st.get("successful_files_count"), "fail:", st.get("failed_files_count"))
        if state in ("Completed", "Failed"):
            return st
        if time.time() - t0 > max_wait_s:
            raise TimeoutError("Timed out waiting for job completion")
        time.sleep(sleep_s)

status = poll_status(JOB_ID)
print(json.dumps(status, indent=2)[:1500])
# Out:
# state: Completed | success: 1 fail: 0
# {
#   "job_state": "Completed",
#   "created_at": "2026-03-05T22:06:21.189764+00:00",
#   "updated_at": "2026-03-05T22:07:25.623314+00:00",
#   "job_id": "20260305_ef61b052-ec65-443b-9be1-7edd1f651b63",
#   "total_files": 1,
#   "successful_files_count": 1,
#   "failed_files_count": 0,
#   "storage_container_type": "Azure_V1",
#   "error_message": "",
#   "job_details": [
#     {
#       "inputs": [
#         {
#           "file_name": "audio.mp3",
#           "file_id": "0"
#         }
#       ],
#       "outputs": [
#         {
#           "file_name": "0.json",
#           "file_id": "0.json"
#         }
#       ],
#       "state": "Success",
#       "error_message": "",
#       "exception_name": null
#     }
#   ]
# }

# %%
if status["job_state"] != "Completed":
    raise RuntimeError(f"Job did not complete successfully: {status.get('error_message')}")

# Collect output filenames
output_files = []
for jd in (status.get("job_details") or []):
    for out in (jd.get("outputs") or []):
        if out.get("file_name"):
            output_files.append(out["file_name"])

# Fallback: if outputs missing, try requesting download for your input name (some systems mirror names)
if not output_files:
    output_files = [AUDIO_PATH.name]

print("Output files:", output_files)

dl = requests.post(
    "https://api.sarvam.ai/speech-to-text/job/v1/download-files",
    headers=HEADERS_JSON,
    json={"job_id": JOB_ID, "files": output_files},
    timeout=60
)
print("download-files:", dl.status_code, dl.text[:500])
dl.raise_for_status()
dl_info = dl.json()

download_urls = dl_info["download_urls"]
print("Got download URLs for:", list(download_urls.keys()))
# Out:
# Output files: ['0.json']
# download-files: 200 {"job_id":"20260305_ef61b052-ec65-443b-9be1-7edd1f651b63","job_state":"Completed","download_urls":{"0.json":{"file_url":"https://appsprodpublicsa.blob.core.windows.net/bulk-upload-storage/jobs/2026-03-05/SPEECH_TO_TEXT_BULK/ef61b052-ec65-443b-9be1-7edd1f651b63/outputs/0.json?se=2026-03-05T23%3A07%3A36Z&sp=r&sv=2025-05-05&sr=b&sig=E7GFG5IwUG30cHVSdFjYfnCgHmC5YzLPik68%2B5TOjDo%3D","file_metadata":null}},"storage_container_type":"Azure_V1"}
# Got download URLs for: ['0.json']

# %%
import requests

results = {}

for fname, meta in download_urls.items():
    # meta is like {"file_url": "...", "file_metadata": ...}
    url = meta["file_url"] if isinstance(meta, dict) and "file_url" in meta else meta
    print("Downloading:", fname, "->", url[:120], "...")

    r = requests.get(url, timeout=180)
    r.raise_for_status()

    try:
        results[fname] = r.json()
    except Exception:
        results[fname] = {"raw_text": r.text}

print("Downloaded results:", list(results.keys()))
# Out:
# Downloading: 0.json -> https://appsprodpublicsa.blob.core.windows.net/bulk-upload-storage/jobs/2026-03-05/SPEECH_TO_TEXT_BULK/ef61b052-ec65-443 ...
# Downloaded results: ['0.json']

# %%
results
# Out:
# {'0.json': {'request_id': '20260305_904e47b3-7966-48c2-b0df-8152108a4e0c',
#   'transcript': 'ओम् भद्रं कर्णेभिश्रृणुजामदेवाः भद्रं पश्येमाक्षभिर्यजत्राः स्थिरैरंगैस्तुष्टुभागं सस्तनोभिः यशैवदेवहितंयदायुः स्वस्तिन इन्द्रो वृद्धश्रवाः स्वस्तिनः पूषा विश्ववेदाः स्वस्तिनस्ताक्ष्यो अरिष्टनेमिः स्वस्तिनो बृहस्पतिर्दधातु ओम् शांति शांति शांतिः ओम् लम् नमस्ते गणपतजे त्वमेव प्रत्यक्षं तत्त्वमसि त्वमेव केवलं कर्तासि त्वमेव केवलं धर्तासि त्वमेव केवलं हर्तासि त्वमेव सर्वं खल्विदं ब्रह्मासि त्वं साक्षात् आत्मासि नित्यं ऋतं वच्मि सत्यं वच्मि अवक्त्वं मां अववक्तारं अवश्रोतारं अवधातारं अवधातारं वानूचानमवशिष्यम् अवपश्चात्तात् अवपुरस्तात् अवोत् उत्तरात्ताते अवदक्षिणात्ताते अवचोर्ध्वात्ताते अवाधरात्ता सर्वतो मां पाहि पाहि समन्तात् त्वं वाङ्मयस्त्वं चिन्मयः त्वमानन्दमयस्त्वं ब्रह्ममयः त्वं सत् चिदानं
#     'जस मिध्भिर्यजति स सर्वं लभते स सर्वं लभते अष्टौ ब्राह्मणान् सम्यग्ग्राहगित्वा',
#     'सूर्यवर्चस्वी भवति सूर्यग्रहे महानद्यां प्रतिमा सन्निधौ वा जप्त्वा सिद्ध मंत्रो भवति महाविग्धात्प्रमुच्यते महा',
#     'दोषात् प्रमुच्यते महापापात् प्रमुच्यते महाप्रत्यवाजत् प्रमुच्यते',
#     'ससर्वविद्भवति ससर्वविद्भवति य एवं वेदा भद्रं कर्ण्डेभिश्रुणुजामदेवाः भद्रं पश्येमाक्षभिल्यजत्राः स्थिरैरङ्गैस्तुष्टुवागुं',
#     'स्वस्तनूभिः यशेमदेवहितंयदायुः स्वस्तिन इन्द्रो वृद्धश्रवाः स्वस्तिनः पूषाविश्ववेदाः स्वस्तिनस्तार्क्यो अरिष्ट',
#     'पठनेमिः स्वस्तिनो बृहस्पतिर्दधातु ओम् शांति शांति शांतिः'],
#    'start_time_seconds': [8.39,
#     22.56,
#     36.07,
#     49.83,
#     65.76,
#     81.28,
#     99.52,
#     110.15,
#     122.34,
#     137.22,
#     156.87,
#     169.67,
#     182.08,
#     197.86,
#     213.51,
#     226.53,
#     242.91,
#     260.39,
#     278.18,
#     295.52,
#     307.52,
#     320.77,
#     337.92,
#     357.76,
#     375.07,
#     391.27,
#     408.26,
#     418.63,
#     430.95,
#     445.63,
#     455.97,
#     472.58,
#     484.64,
#     503.84,
#     520.93],
#    'end_time_seconds': [22.56,
#     36.07,
#     49.83,
#     65.76,
#     81.28,
#     99.52,
#     110.15,
#     122.34,
#     137.22,
#     156.87,
#     169.67,
#     182.08,
#     197.86,
#     213.51,
#     226.53,
#     242.91,
#     260.39,
#     278.18,
#     295.52,
#     307.52,
#     320.77,
#     337.92,
#     357.76,
#     375.07,
#     391.27,
#     408.26,
#     418.63,
#     430.95,
#     445.63,
#     455.97,
#     472.58,
#     484.64,
#     503.84,
#     520.93,
#     530.78]},
#   'diarized_transcript': None,
#   'language_code': 'sa-IN',
#   'language_probability': None}}

# %%
results['0.json'].get('timestamps').get('end_time_seconds')[0] - results['0.json'].get('timestamps').get('start_time_seconds')[0]
# Out:
# 14.169999999999998

# %%
for i in range(len(results['0.json'].get('timestamps').get('words'))):
    print(i)
    print(results['0.json'].get('timestamps').get('words')[0].split(' ')[i], len(results['0.json'].get('timestamps').get('words')[0].split(' ')[i]))
# Out:
# 0
# ओम् 3
# 1
# भद्रं 5
# 2
# कर्णेभिश्रृणुजामदेवाः 21
# 3
# भद्रं 5
# 4
# पश्येमाक्षभिर्यजत्राः 21
# 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[101], line 3
#       1 for i in range(len(results['0.json'].get('timestamps').get('words'))):
#       2     print(i)
# ----> 3     print(results['0.json'].get('timestamps').get('words')[0].split(' ')[i], len(results['0.json'].get('timestamps').get('words')[0].split(' ')[i]))
#
# IndexError: list index out of range
